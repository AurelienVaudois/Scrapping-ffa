# %%
from ..src.utils.ffa_fast import get_all_results_fast as get_all_athlete_results
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from ..src.utils.ffa_fast import get_all_results_fast as get_all_athlete_results
#
# ImportError: attempted relative import with no known parent package

# %%
from pathlib import Path
import sys
from Src.utils.ffa_fast import get_all_results_fast as get_all_athlete_results

# Ajoute le dossier parent (racine du projet) au PYTHONPATH
sys.path.append(str(Path.cwd().parent))

# Import depuis /Src (adapter le nom du module/fonction si besoin)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 from pathlib import Path
#       2 import sys
# ----> 3 from Src.utils.ffa_fast import get_all_results_fast as get_all_athlete_results
#       5 # Ajoute le dossier parent (racine du projet) au PYTHONPATH
#       6 sys.path.append(str(Path.cwd().parent))
#
# ModuleNotFoundError: No module named 'Src'
